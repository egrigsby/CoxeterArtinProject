# %% [markdown]
# # Setup Correct Python and Torch install for GPU Usage

# %%
# !pwd    #print working directory
# Out:
# /home/linrya/CoxeterArtinProject

# %%
# !python --version
# Out:
# Python 3.12.5

# %% [markdown]
# **Ensure that this shows some GPU, this indicates that the Kernel selected for the Notebook in VSCode is running in a node with a GPU**

# %%
# !nvidia-smi
# Out:
# Thu Jun 18 22:51:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-PCIE-40GB          Off |   00000000:CA:00.0 Off |                    0 |
# | N/A   22C    P0             55W /  250W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------
# accelerate                    1.14.0
# aiohappyeyeballs              2.6.2
# aiohttp                       3.14.1
# aiosignal                     1.4.0
# annotated-doc                 0.0.4
# annotated-types               0.7.0
# anyio                         4.4.0
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asttokens                     2.4.1
# async-lru                     2.0.4
# attrs                         24.2.0
# Babel                         2.14.0
# beartype                      0.22.9
# beautifulsoup4                4.12.3
# better-abc                    0.0.3
# bleach                        6.1.0
# Brotli                        1.1.0
# cached-property               1.5.2
# certifi                       2024.8.30
# cffi                          1.17.1
# charset-normalizer            3.3.2
# click                         8.4.1
# comm                          0.2.2
# contourpy                     1.3.3
# cycler                        0.12.1
# datasets                      5.0.0
# debugpy                       1.8.5
# decorator                     5.1.1
# defusedxml                    0.7.1
# dill                          0.4.1
# einops                        0.8.2
# entrypoints                   0.4
# exceptiongroup                1.2.2
# executing                     2.1.0
# fancy-einsum                  0.0.3
# fastjsonschema                2.20.0
# filelock                      3.29.0
# fonttools                     4.63.0
# fqdn                          1.5.1
# frozenlist                    1.8.0
# fsspec                        2026.4.0
# gitdb                         4.0.12
# GitPython                     3.1.50
# h11                           0.14.0
# h2                            4.1.0
# hf-xet                        1.5.1
# hpack                         4.0.0
# httpcore                      1.0.5
# httpx                         0.27.2
# huggingface_hub               1.20.1
# hyperframe                    6.0.1
# idna                          3.8
# import-ipynb                  0.2
# importlib_metadata            8.4.0
# importlib_resources           6.4.5
# ipykernel                     6.29.5
# ipython                       8.27.0
# ipywidgets                    8.1.5
# isoduration                   20.11.0
# jaxtyping                     0.3.11
# jedi                          0.19.1
# Jinja2                        3.1.4
# joblib                        1.5.3
# json5                         0.9.25
# jsonpointer                   3.0.0
# jsonschema                    4.23.0
# jsonschema-specifications     2023.12.1
# jupyter                       1.1.1
# jupyter_client                8.6.2
# jupyter-console               6.6.3
# jupyter_core                  5.7.2
# jupyter-events                0.10.0
# jupyter-lsp                   2.2.5
# jupyter_server                2.14.2
# jupyter_server_terminals      0.5.3
# jupyterlab                    4.2.5
# jupyterlab_pygments           0.3.0
# jupyterlab_server             2.27.3
# jupyterlab_widgets            3.0.13
# kiwisolver                    1.5.0
# markdown-it-py                4.2.0
# MarkupSafe                    2.1.5
# matplotlib                    3.11.0
# matplotlib-inline             0.1.7
# mdurl                         0.1.2
# mistune                       3.0.2
# mpmath                        1.3.0
# multidict                     6.7.1
# multiprocess                  0.70.19
# narwhals                      2.22.1
# nbclient                      0.10.0
# nbconvert                     7.16.4
# nbformat                      5.10.4
# neel_plotly                   0.0.0
# nest_asyncio                  1.6.0
# networkx                      3.6.1
# notebook                      7.2.2
# notebook_shim                 0.2.4
# numpy                         2.4.6
# nvidia-cublas-cu12            12.6.4.1
# nvidia-cuda-cupti-cu12        12.6.80
# nvidia-cuda-nvrtc-cu12        12.6.77
# nvidia-cuda-runtime-cu12      12.6.77
# nvidia-cudnn-cu12             9.5.1.17
# nvidia-cufft-cu12             11.3.0.4
# nvidia-cufile-cu12            1.11.1.6
# nvidia-curand-cu12            10.3.7.77
# nvidia-cusolver-cu12          11.7.1.2
# nvidia-cusparse-cu12          12.5.4.2
# nvidia-cusparselt-cu12        0.6.3
# nvidia-nccl-cu12              2.26.2
# nvidia-nvjitlink-cu12         12.6.85
# nvidia-nvshmem-cu12           3.4.5
# nvidia-nvtx-cu12              12.6.77
# overrides                     7.7.0
# packaging                     24.1
# pandas                        3.0.3
# pandocfilters                 1.5.0
# parso                         0.8.4
# pexpect                       4.9.0
# pickleshare                   0.7.5
# pillow                        12.2.0
# pip                           24.2
# pkgutil_resolve_name          1.3.10
# platformdirs                  4.3.2
# plotly                        6.8.0
# prometheus_client             0.20.0
# prompt_toolkit                3.0.47
# propcache                     0.5.2
# protobuf                      7.35.1
# psutil                        6.0.0
# ptyprocess                    0.7.0
# pure_eval                     0.2.3
# pyarrow                       24.0.0
# pycparser                     2.22
# pydantic                      2.13.4
# pydantic_core                 2.46.4
# Pygments                      2.18.0
# pyparsing                     3.3.2
# PySocks                       1.7.1
# python-dateutil               2.9.0
# python-json-logger            2.0.7
# pytz                          2024.2
# PyYAML                        6.0.2
# pyzmq                         26.2.0
# referencing                   0.35.1
# regex                         2026.5.9
# requests                      2.32.3
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rich                          15.0.0
# rpds-py                       0.20.0
# safetensors                   0.8.0
# scikit-learn                  1.9.0
# scipy                         1.17.1
# Send2Trash                    1.8.3
# sentencepiece                 0.2.1
# sentry-sdk                    2.63.0
# setuptools                    73.0.1
# shellingham                   1.5.4
# six                           1.16.0
# smmap                         5.0.3
# sniffio                       1.3.1
# soupsieve                     2.5
# stack-data                    0.6.2
# sympy                         1.14.0
# terminado                     0.18.1
# threadpoolctl                 3.6.0
# tinycss2                      1.3.0
# tokenizers                    0.22.2
# tomli                         2.0.1
# torchvision                   0.22.1
# tornado                       6.4.1
# tqdm                          4.68.3
# traitlets                     5.14.3
# transformer-lens              3.4.0
# transformers-stream-generator 0.0.5
# typeguard                     4.5.2
# typer                         0.25.1
# types-python-dateutil         2.9.0.20240906
# typing_extensions             4.15.0
# typing-inspection             0.4.2
# typing-utils                  0.1.0
# uri-template                  1.3.0
# urllib3                       2.2.2
# wadler_lindig                 0.1.7
# wandb                         0.27.2
# wcwidth                       0.2.13
# webcolors                     24.8.0
# webencodings                  0.5.1
# websocket-client              1.8.0
# wheel                         0.44.0
# widgetsnbextension            4.0.13
# xxhash                        3.7.0
# yarl                          1.24.2
# zipp                          3.20.1
# zstandard                     0.23.0

# %%
# !conda list
# Note: Packages are stored in: /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages
# Out:
# # packages in environment at /m31/modules/miniconda/3/envs/jupyter:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# anyio                     4.4.0              pyhd8ed1ab_0    conda-forge
# argon2-cffi               23.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0          py312h66e93f0_5    conda-forge
# arrow                     1.3.0              pyhd8ed1ab_0    conda-forge
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# async-lru                 2.0.4              pyhd8ed1ab_0    conda-forge
# attrs                     24.2.0             pyh71513ae_0    conda-forge
# babel                     2.14.0             pyhd8ed1ab_0    conda-forge
# beautifulsoup4            4.12.3             pyha770c72_0    conda-forge
# bleach                    6.1.0              pyhd8ed1ab_0    conda-forge
# brotli-python             1.1.0           py312h2ec8cdc_2    conda-forge
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# ca-certificates           2024.8.30            hbcca054_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# certifi                   2024.8.30          pyhd8ed1ab_0    conda-forge
# cffi                      1.17.1          py312h06ac9bb_0    conda-forge
# charset-normalizer        3.3.2              pyhd8ed1ab_0    conda-forge
# comm                      0.2.2              pyhd8ed1ab_0    conda-forge
# debugpy                   1.8.5           py312h2ec8cdc_1    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# exceptiongroup            1.2.2              pyhd8ed1ab_0    conda-forge
# executing                 2.1.0              pyhd8ed1ab_0    conda-forge
# fqdn                      1.5.1              pyhd8ed1ab_0    conda-forge
# h11                       0.14.0             pyhd8ed1ab_0    conda-forge
# h2                        4.1.0              pyhd8ed1ab_0    conda-forge
# hpack                     4.0.0              pyh9f0ad1d_0    conda-forge
# httpcore                  1.0.5              pyhd8ed1ab_0    conda-forge
# httpx                     0.27.2             pyhd8ed1ab_0    conda-forge
# hyperframe                6.0.1              pyhd8ed1ab_0    conda-forge
# idna                      3.8                pyhd8ed1ab_0    conda-forge
# importlib-metadata        8.4.0              pyha770c72_0    conda-forge
# importlib_metadata        8.4.0                hd8ed1ab_0    conda-forge
# importlib_resources       6.4.5              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.29.5             pyh3099207_0    conda-forge
# ipython                   8.27.0             pyh707e725_0    conda-forge
# ipywidgets                8.1.5              pyhd8ed1ab_0    conda-forge
# isoduration               20.11.0            pyhd8ed1ab_0    conda-forge
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# jinja2                    3.1.4              pyhd8ed1ab_0    conda-forge
# json5                     0.9.25             pyhd8ed1ab_0    conda-forge
# jsonpointer               3.0.0           py312h7900ff3_1    conda-forge
# jsonschema                4.23.0             pyhd8ed1ab_0    conda-forge
# jsonschema-specifications 2023.12.1          pyhd8ed1ab_0    conda-forge
# jsonschema-with-format-nongpl 4.23.0               hd8ed1ab_0    conda-forge
# jupyter                   1.1.1              pyhd8ed1ab_0    conda-forge
# jupyter-lsp               2.2.5              pyhd8ed1ab_0    conda-forge
# jupyter_client            8.6.2              pyhd8ed1ab_0    conda-forge
# jupyter_console           6.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.2           py312h7900ff3_0    conda-forge
# jupyter_events            0.10.0             pyhd8ed1ab_0    conda-forge
# jupyter_server            2.14.2             pyhd8ed1ab_0    conda-forge
# jupyter_server_terminals  0.5.3              pyhd8ed1ab_0    conda-forge
# jupyterlab                4.2.5              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.3.0              pyhd8ed1ab_1    conda-forge
# jupyterlab_server         2.27.3             pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        3.0.13             pyhd8ed1ab_0    conda-forge
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# krb5                      1.21.3               h659f571_0    conda-forge
# ld_impl_linux-64          2.40                 hf3520f5_7    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libexpat                  2.6.3                h5888daf_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc                    14.1.0               h77fa898_1    conda-forge
# libgcc-ng                 14.1.0               h69a702a_1    conda-forge
# libgomp                   14.1.0               h77fa898_1    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libsodium                 1.0.20               h4ab18f5_0    conda-forge
# libsqlite                 3.46.1               hadc24fc_0    conda-forge
# libstdcxx                 14.1.0               hc0a3c3a_1    conda-forge
# libstdcxx-ng              14.1.0               h4852527_1    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libzlib                   1.3.1                h4ab18f5_1    conda-forge
# markupsafe                2.1.5           py312h66e93f0_1    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_0    conda-forge
# mistune                   3.0.2              pyhd8ed1ab_0    conda-forge
# nbclient                  0.10.0             pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.16.4             pyhd8ed1ab_1    conda-forge
# nbformat                  5.10.4             pyhd8ed1ab_0    conda-forge
# ncurses                   6.5                  he02047a_1    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# notebook                  7.2.2              pyhd8ed1ab_0    conda-forge
# notebook-shim             0.2.4              pyhd8ed1ab_0    conda-forge
# openssl                   3.3.2                hb9d3cd8_0    conda-forge
# overrides                 7.7.0              pyhd8ed1ab_0    conda-forge
# packaging                 24.1               pyhd8ed1ab_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# parso                     0.8.4              pyhd8ed1ab_0    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pip                       24.2               pyh8b19718_1    conda-forge
# pkgutil-resolve-name      1.3.10             pyhd8ed1ab_1    conda-forge
# platformdirs              4.3.2              pyhd8ed1ab_0    conda-forge
# prometheus_client         0.20.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.47             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.47               hd8ed1ab_0    conda-forge
# psutil                    6.0.0           py312h66e93f0_1    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_0    conda-forge
# pycparser                 2.22               pyhd8ed1ab_0    conda-forge
# pygments                  2.18.0             pyhd8ed1ab_0    conda-forge
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# python                    3.12.5          h2ad013b_0_cpython    conda-forge
# python-dateutil           2.9.0              pyhd8ed1ab_0    conda-forge
# python-fastjsonschema     2.20.0             pyhd8ed1ab_0    conda-forge
# python-json-logger        2.0.7              pyhd8ed1ab_0    conda-forge
# python_abi                3.12                    5_cp312    conda-forge
# pytz                      2024.2             pyhd8ed1ab_0    conda-forge
# pyyaml                    6.0.2           py312h66e93f0_1    conda-forge
# pyzmq                     26.2.0          py312hbf22597_2    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# referencing               0.35.1             pyhd8ed1ab_0    conda-forge
# requests                  2.32.3             pyhd8ed1ab_0    conda-forge
# rfc3339-validator         0.1.4              pyhd8ed1ab_0    conda-forge
# rfc3986-validator         0.1.1              pyh9f0ad1d_0    conda-forge
# rpds-py                   0.20.0          py312h12e396e_1    conda-forge
# send2trash                1.8.3              pyh0d859eb_0    conda-forge
# setuptools                73.0.1             pyhd8ed1ab_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sniffio                   1.3.1              pyhd8ed1ab_0    conda-forge
# soupsieve                 2.5                pyhd8ed1ab_1    conda-forge
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# terminado                 0.18.1             pyh0d859eb_0    conda-forge
# tinycss2                  1.3.0              pyhd8ed1ab_0    conda-forge
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tomli                     2.0.1              pyhd8ed1ab_0    conda-forge
# tornado                   6.4.1           py312h66e93f0_1    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_0    conda-forge
# types-python-dateutil     2.9.0.20240906     pyhd8ed1ab_0    conda-forge
# typing-extensions         4.12.2               hd8ed1ab_0    conda-forge
# typing_extensions         4.12.2             pyha770c72_0    conda-forge
# typing_utils              0.1.0              pyhd8ed1ab_0    conda-forge
# tzdata                    2024a                h8827d51_1    conda-forge
# uri-template              1.3.0              pyhd8ed1ab_0    conda-forge
# urllib3                   2.2.2              pyhd8ed1ab_1    conda-forge
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# webcolors                 24.8.0             pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1              pyhd8ed1ab_2    conda-forge
# websocket-client          1.8.0              pyhd8ed1ab_0    conda-forge
# wheel                     0.44.0             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.13             pyhd8ed1ab_0    conda-forge
# xz                        5.2.6                h166bdaf_0    conda-forge
# yaml                      0.2.5                h7f98852_2    conda-forge
# zeromq                    4.3.5                ha4adb4c_5    conda-forge
# zipp                      3.20.1             pyhd8ed1ab_0    conda-forge
# zstandard                 0.23.0          py312hef9b889_1    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge

# %% [markdown]
# **Using Cuda 12.8 with PyTorch**

# %%
# %pip install torch==2.7.1
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch==2.7.1
#   Using cached torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /home/linrya/.local/lib/python3.12/site-packages (from torch==2.7.1) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/linrya/.local/lib/python3.12/site-packages (from torch==2.7.1) (4.15.0)
# Requirement already satisfied: setuptools in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from torch==2.7.1) (73.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/linrya/.local/lib/python3.12/site-packages (from torch==2.7.1) (1.14.0)
# Requirement already satisfied: networkx in /home/linrya/.local/lib/python3.12/site-packages (from torch==2.7.1) (3.6.1)
# Requirement already satisfied: jinja2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from torch==2.7.1) (3.1.4)
# Requirement already satisfied: fsspec in /home/linrya/.local/lib/python3.12/site-packages (from torch==2.7.1) (2026.4.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch==2.7.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch==2.7.1)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch==2.7.1)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch==2.7.1)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch==2.7.1)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch==2.7.1)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch==2.7.1)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch==2.7.1)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch==2.7.1)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch==2.7.1)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch==2.7.1)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch==2.7.1)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch==2.7.1)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch==2.7.1)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch==2.7.1)
#   Using cached triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/linrya/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jinja2->torch==2.7.1) (2.1.5)
# Using cached torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl (821.0 MB)
# Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.9
#     Uninstalling nvidia-nccl-cu12-2.28.9:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.9
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.13.1.3
#     Uninstalling nvidia-cufile-cu12-1.13.1.3:
#       Successfully uninstalled nvidia-cufile-cu12-1.13.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.19.0.56
#     Uninstalling nvidia-cudnn-cu12-9.19.0.56:
#       Successfully uninstalled nvidia-cudnn-cu12-9.19.0.56
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformer-lens 3.4.0 requires transformers>=5.4.0, which is not installed.
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 torch-2.7.1 triton-3.3.1
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/linrya/.local/lib/python3.12/site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **test to see if torch is installed:**

# %%
import torch
# Out:
# Name: torch
# Version: 2.7.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /home/linrya/.local/lib/python3.12/site-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-cufile-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, setuptools, sympy, triton, typing-extensions
# Required-by: accelerate, neel_plotly, torchvision, transformer-lens
# Note: you may need to restart the kernel to use updated packages.

# %%
# Note: V100 GPU too old for Conda 12.8
# Use: A100 or higher
# !python -c "import torch; print(torch.cuda.is_available(), torch.cuda.get_device_name(0))"
# Out:
# True NVIDIA A100-PCIE-40GB

# %% [markdown]
# # Other Required Packages
#
# Note: no need to run these cells once the CoxeterEnv (python environment) has been setup, since these packages are already installed

# %% [markdown]
# ## Code Generation

# %%
# %pip install pandas numpy import-ipynb matplotlib scikit-learn plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/linrya/.local/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy in /home/linrya/.local/lib/python3.12/site-packages (2.4.6)
# Requirement already satisfied: import-ipynb in /home/linrya/.local/lib/python3.12/site-packages (0.2)
# Requirement already satisfied: matplotlib in /home/linrya/.local/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: scikit-learn in /home/linrya/.local/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: plotly in /home/linrya/.local/lib/python3.12/site-packages (6.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: IPython in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from import-ipynb) (8.27.0)
# Requirement already satisfied: nbformat in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/linrya/.local/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/linrya/.local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/linrya/.local/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/linrya/.local/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=9 in /home/linrya/.local/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/linrya/.local/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in /home/linrya/.local/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in /home/linrya/.local/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /home/linrya/.local/lib/python3.12/site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/linrya/.local/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: decorator in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (2.18.0)
# Requirement already satisfied: stack-data in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from nbformat->import-ipynb) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from nbformat->import-ipynb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from nbformat->import-ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from stack-data->IPython->import-ipynb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from stack-data->IPython->import-ipynb) (2.4.1)
# Requirement already satisfied: pure-eval in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from stack-data->IPython->import-ipynb) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Transformer Training/ML Packages

# %%
# %pip install transformer-lens einops fancy-einsum tqdm plotly transformers datasets ipython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformer-lens in /home/linrya/.local/lib/python3.12/site-packages (3.4.0)
# Requirement already satisfied: einops in /home/linrya/.local/lib/python3.12/site-packages (0.8.2)
# Requirement already satisfied: fancy-einsum in /home/linrya/.local/lib/python3.12/site-packages (0.0.3)
# Requirement already satisfied: tqdm in /home/linrya/.local/lib/python3.12/site-packages (4.68.3)
# Requirement already satisfied: plotly in /home/linrya/.local/lib/python3.12/site-packages (6.8.0)
# Collecting transformers
#   Using cached transformers-5.12.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: datasets in /home/linrya/.local/lib/python3.12/site-packages (5.0.0)
# Requirement already satisfied: ipython in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (8.27.0)
# Requirement already satisfied: accelerate>=0.23.0 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (1.14.0)
# Requirement already satisfied: beartype>=0.14.1 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.22.9)
# Requirement already satisfied: better-abc>=0.0.3 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (1.20.1)
# Requirement already satisfied: jaxtyping>=0.2.11 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.3.11)
# Requirement already satisfied: numpy>=1.26 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (2.4.6)
# Requirement already satisfied: packaging>=23.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from transformer-lens) (24.1)
# Requirement already satisfied: pandas>=1.1.5 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (3.0.3)
# Requirement already satisfied: protobuf>=3.20.0 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (7.35.1)
# Requirement already satisfied: rich>=12.6.0 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (15.0.0)
# Requirement already satisfied: sentencepiece in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.2.1)
# Requirement already satisfied: torch>=2.6 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (2.7.1)
# Requirement already satisfied: torchvision<0.23,>=0.22 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.22.1)
# Requirement already satisfied: transformers-stream-generator<0.1,>=0.0.5 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.0.5)
# Requirement already satisfied: typeguard<5,>=4.2 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (4.5.2)
# Requirement already satisfied: typing-extensions in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (4.15.0)
# Requirement already satisfied: wandb>=0.13.5 in /home/linrya/.local/lib/python3.12/site-packages (from transformer-lens) (0.27.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/linrya/.local/lib/python3.12/site-packages (from plotly) (2.22.1)
# Requirement already satisfied: pyyaml>=5.1 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in /home/linrya/.local/lib/python3.12/site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/linrya/.local/lib/python3.12/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /home/linrya/.local/lib/python3.12/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/linrya/.local/lib/python3.12/site-packages (from transformers) (0.8.0)
# Requirement already satisfied: filelock in /home/linrya/.local/lib/python3.12/site-packages (from datasets) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/linrya/.local/lib/python3.12/site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/linrya/.local/lib/python3.12/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from datasets) (0.27.2)
# Requirement already satisfied: xxhash in /home/linrya/.local/lib/python3.12/site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/linrya/.local/lib/python3.12/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /home/linrya/.local/lib/python3.12/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2026.4.0)
# Requirement already satisfied: decorator in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (2.18.0)
# Requirement already satisfied: stack-data in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: psutil in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer-lens) (6.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/linrya/.local/lib/python3.12/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: anyio in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.4.0)
# Requirement already satisfied: certifi in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.5)
# Requirement already satisfied: idna in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.8)
# Requirement already satisfied: sniffio in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: click>=8.4.0 in /home/linrya/.local/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->transformer-lens) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /home/linrya/.local/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->transformer-lens) (1.5.1)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/linrya/.local/lib/python3.12/site-packages (from jaxtyping>=0.2.11->transformer-lens) (0.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from pandas>=1.1.5->transformer-lens) (2.9.0)
# Requirement already satisfied: ptyprocess>=0.5 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/linrya/.local/lib/python3.12/site-packages (from rich>=12.6.0->transformer-lens) (4.2.0)
# Requirement already satisfied: setuptools in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (73.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (1.14.0)
# Requirement already satisfied: networkx in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (3.6.1)
# Requirement already satisfied: jinja2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/linrya/.local/lib/python3.12/site-packages (from torch>=2.6->transformer-lens) (3.3.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/linrya/.local/lib/python3.12/site-packages (from torchvision<0.23,>=0.22->transformer-lens) (12.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/linrya/.local/lib/python3.12/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/linrya/.local/lib/python3.12/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/linrya/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens) (3.1.50)
# Requirement already satisfied: platformdirs in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens) (4.3.2)
# Requirement already satisfied: pydantic<3,>=2.6 in /home/linrya/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens) (2.13.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/linrya/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens) (2.63.0)
# Requirement already satisfied: executing>=1.2.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from stack-data->ipython) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from stack-data->ipython) (0.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/linrya/.local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/linrya/.local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/linrya/.local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/linrya/.local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/linrya/.local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/linrya/.local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: six>=1.12.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/linrya/.local/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /home/linrya/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/linrya/.local/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.13.5->transformer-lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/linrya/.local/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.13.5->transformer-lens) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/linrya/.local/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.13.5->transformer-lens) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/linrya/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.6->transformer-lens) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jinja2->torch>=2.6->transformer-lens) (2.1.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/linrya/.local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (5.0.3)
# Using cached transformers-5.12.1-py3-none-any.whl (11.2 MB)
# Installing collected packages: transformers
# Successfully installed transformers-5.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install git+https://github.com/neelnanda-io/neel-plotly.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/neelnanda-io/neel-plotly.git
#   Cloning https://github.com/neelnanda-io/neel-plotly.git to /tmp/pip-req-build-9tp16pcv
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/neel-plotly.git /tmp/pip-req-build-9tp16pcv
#   Resolved https://github.com/neelnanda-io/neel-plotly.git to commit 6dc24b26f8dec991908479d7445dae496b3430b7
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /home/linrya/.local/lib/python3.12/site-packages (from neel_plotly==0.0.0) (0.8.2)
# Requirement already satisfied: numpy in /home/linrya/.local/lib/python3.12/site-packages (from neel_plotly==0.0.0) (2.4.6)
# Requirement already satisfied: torch in /home/linrya/.local/lib/python3.12/site-packages (from neel_plotly==0.0.0) (2.7.1)
# Requirement already satisfied: plotly in /home/linrya/.local/lib/python3.12/site-packages (from neel_plotly==0.0.0) (6.8.0)
# Requirement already satisfied: tqdm in /home/linrya/.local/lib/python3.12/site-packages (from neel_plotly==0.0.0) (4.68.3)
# Requirement already satisfied: pandas in /home/linrya/.local/lib/python3.12/site-packages (from neel_plotly==0.0.0) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from pandas->neel_plotly==0.0.0) (2.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/linrya/.local/lib/python3.12/site-packages (from plotly->neel_plotly==0.0.0) (2.22.1)
# Requirement already satisfied: packaging in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from plotly->neel_plotly==0.0.0) (24.1)
# Requirement already satisfied: filelock in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (4.15.0)
# Requirement already satisfied: setuptools in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (73.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (1.14.0)
# Requirement already satisfied: networkx in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (3.1.4)
# Requirement already satisfied: fsspec in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/linrya/.local/lib/python3.12/site-packages (from torch->neel_plotly==0.0.0) (3.3.1)
# Requirement already satisfied: six>=1.5 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->neel_plotly==0.0.0) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/linrya/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch->neel_plotly==0.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /m31/modules/miniconda/3/envs/jupyter/lib/python3.12/site-packages (from jinja2->torch->neel_plotly==0.0.0) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
