# %% [markdown]
# # Setup Correct Python and Torch install for GPU Usage

# %%
# !pwd    #print working directory

# %%
# !python --version
# Out:
# Python 3.11.13

# %% [markdown]
# **Ensure that this shows some GPU, this indicates that the Kernel selected for the Notebook in VSCode is running in a node with a GPU**

# %%
# !nvidia-smi
# Out:
# Sat Jun 28 16:50:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-PCIE-40GB          Off |   00000000:17:00.0 Off |                    0 |
# | N/A   23C    P0             34W /  250W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------
# accelerate                    1.8.1
# aiohappyeyeballs              2.6.1
# aiohttp                       3.12.13
# aiosignal                     1.3.2
# annotated-types               0.7.0
# anyio                         4.9.0
# argon2-cffi                   25.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asttokens                     3.0.0
# async-lru                     2.0.5
# attrs                         25.3.0
# babel                         2.17.0
# beartype                      0.14.1
# beautifulsoup4                4.13.4
# better-abc                    0.0.3
# bleach                        6.2.0
# certifi                       2025.6.15
# cffi                          1.17.1
# charset-normalizer            3.4.2
# click                         8.2.1
# comm                          0.2.2
# contourpy                     1.3.2
# cycler                        0.12.1
# datasets                      3.6.0
# debugpy                       1.8.14
# decorator                     5.2.1
# defusedxml                    0.7.1
# dill                          0.3.8
# einops                        0.8.1
# executing                     2.2.0
# fancy-einsum                  0.0.3
# fastjsonschema                2.21.1
# filelock                      3.13.1
# fonttools                     4.58.4
# fqdn                          1.5.1
# frozenlist                    1.7.0
# fsspec                        2024.6.1
# gitdb                         4.0.12
# GitPython                     3.1.44
# h11                           0.16.0
# hf-xet                        1.1.5
# httpcore                      1.0.9
# httpx                         0.28.1
# huggingface-hub               0.33.1
# idna                          3.10
# import-ipynb                  0.2
# ipykernel                     6.29.5
# ipython                       9.3.0
# ipython_pygments_lexers       1.1.1
# ipywidgets                    8.1.7
# isoduration                   20.11.0
# jaxtyping                     0.3.2
# jedi                          0.19.2
# Jinja2                        3.1.6
# joblib                        1.5.1
# json5                         0.12.0
# jsonpointer                   3.0.0
# jsonschema                    4.24.0
# jsonschema-specifications     2025.4.1
# jupyter                       1.1.1
# jupyter_client                8.6.3
# jupyter-console               6.6.3
# jupyter_core                  5.8.1
# jupyter-events                0.12.0
# jupyter-lsp                   2.2.5
# jupyter_server                2.16.0
# jupyter_server_terminals      0.5.3
# jupyterlab                    4.4.4
# jupyterlab_pygments           0.3.0
# jupyterlab_server             2.27.3
# jupyterlab_widgets            3.0.15
# kiwisolver                    1.4.8
# markdown-it-py                3.0.0
# MarkupSafe                    3.0.2
# matplotlib                    3.10.3
# matplotlib-inline             0.1.7
# mdurl                         0.1.2
# mistune                       3.1.3
# mpmath                        1.3.0
# multidict                     6.6.2
# multiprocess                  0.70.16
# narwhals                      1.44.0
# nbclient                      0.10.2
# nbconvert                     7.16.6
# nbformat                      5.10.4
# nest-asyncio                  1.6.0
# networkx                      3.3
# notebook                      7.4.3
# notebook_shim                 0.2.4
# numpy                         1.26.4
# nvidia-cublas-cu12            12.8.3.14
# nvidia-cuda-cupti-cu12        12.8.57
# nvidia-cuda-nvrtc-cu12        12.8.61
# nvidia-cuda-runtime-cu12      12.8.57
# nvidia-cudnn-cu12             9.7.1.26
# nvidia-cufft-cu12             11.3.3.41
# nvidia-cufile-cu12            1.13.0.11
# nvidia-curand-cu12            10.3.9.55
# nvidia-cusolver-cu12          11.7.2.55
# nvidia-cusparse-cu12          12.5.7.53
# nvidia-cusparselt-cu12        0.6.3
# nvidia-nccl-cu12              2.26.2
# nvidia-nvjitlink-cu12         12.8.61
# nvidia-nvtx-cu12              12.8.55
# overrides                     7.7.0
# packaging                     25.0
# pandas                        2.3.0
# pandocfilters                 1.5.1
# parso                         0.8.4
# pexpect                       4.9.0
# pillow                        11.2.1
# pip                           25.1.1
# platformdirs                  4.3.8
# plotly                        6.2.0
# prometheus_client             0.22.1
# prompt_toolkit                3.0.51
# propcache                     0.3.2
# protobuf                      6.31.1
# psutil                        7.0.0
# ptyprocess                    0.7.0
# pure_eval                     0.2.3
# pyarrow                       20.0.0
# pycparser                     2.22
# pydantic                      2.11.7
# pydantic_core                 2.33.2
# Pygments                      2.19.2
# pyparsing                     3.2.3
# python-dateutil               2.9.0.post0
# python-json-logger            3.3.0
# pytz                          2025.2
# PyYAML                        6.0.2
# pyzmq                         27.0.0
# referencing                   0.36.2
# regex                         2024.11.6
# requests                      2.32.4
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rich                          14.0.0
# rpds-py                       0.25.1
# safetensors                   0.5.3
# scikit-learn                  1.7.0
# scipy                         1.16.0
# Send2Trash                    1.8.3
# sentencepiece                 0.2.0
# sentry-sdk                    2.32.0
# setproctitle                  1.3.6
# setuptools                    80.9.0
# six                           1.17.0
# smmap                         5.0.2
# sniffio                       1.3.1
# soupsieve                     2.7
# stack-data                    0.6.3
# sympy                         1.13.3
# terminado                     0.18.1
# threadpoolctl                 3.6.0
# tinycss2                      1.4.0
# tokenizers                    0.21.2
# torch                         2.7.1+cu128
# tornado                       6.5.1
# tqdm                          4.67.1
# traitlets                     5.14.3
# transformer-lens              2.16.1
# transformers                  4.53.0
# transformers-stream-generator 0.0.5
# triton                        3.3.1
# typeguard                     4.4.4
# types-python-dateutil         2.9.0.20250516
# typing_extensions             4.14.0
# typing-inspection             0.4.1
# tzdata                        2025.2
# uri-template                  1.3.0
# urllib3                       2.5.0
# wadler_lindig                 0.1.7
# wandb                         0.20.1
# wcwidth                       0.2.13
# webcolors                     24.11.1
# webencodings                  0.5.1
# websocket-client              1.8.0
# wheel                         0.45.1
# widgetsnbextension            4.0.14
# xxhash                        3.5.0
# yarl                          1.20.1

# %%
# !conda list
# Note: Packages are stored in: /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages
# Out:
# # packages in environment at /projects/expmmllab/CoxeterEnv:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# accelerate                1.8.1                    pypi_0    pypi
# aiohappyeyeballs          2.6.1                    pypi_0    pypi
# aiohttp                   3.12.13                  pypi_0    pypi
# aiosignal                 1.3.2                    pypi_0    pypi
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.9.0                    pypi_0    pypi
# argon2-cffi               25.1.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# arrow                     1.3.0                    pypi_0    pypi
# asttokens                 3.0.0                    pypi_0    pypi
# async-lru                 2.0.5                    pypi_0    pypi
# attrs                     25.3.0                   pypi_0    pypi
# babel                     2.17.0                   pypi_0    pypi
# beartype                  0.14.1                   pypi_0    pypi
# beautifulsoup4            4.13.4                   pypi_0    pypi
# better-abc                0.0.3                    pypi_0    pypi
# bleach                    6.2.0                    pypi_0    pypi
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# ca-certificates           2025.6.15            hbd8a1cb_0    conda-forge
# certifi                   2025.6.15                pypi_0    pypi
# cffi                      1.17.1                   pypi_0    pypi
# charset-normalizer        3.4.2                    pypi_0    pypi
# click                     8.2.1                    pypi_0    pypi
# comm                      0.2.2                    pypi_0    pypi
# contourpy                 1.3.2                    pypi_0    pypi
# cycler                    0.12.1                   pypi_0    pypi
# datasets                  3.6.0                    pypi_0    pypi
# debugpy                   1.8.14                   pypi_0    pypi
# decorator                 5.2.1                    pypi_0    pypi
# defusedxml                0.7.1                    pypi_0    pypi
# dill                      0.3.8                    pypi_0    pypi
# einops                    0.8.1                    pypi_0    pypi
# executing                 2.2.0                    pypi_0    pypi
# fancy-einsum              0.0.3                    pypi_0    pypi
# fastjsonschema            2.21.1                   pypi_0    pypi
# filelock                  3.13.1                   pypi_0    pypi
# fonttools                 4.58.4                   pypi_0    pypi
# fqdn                      1.5.1                    pypi_0    pypi
# frozenlist                1.7.0                    pypi_0    pypi
# fsspec                    2024.6.1                 pypi_0    pypi
# gitdb                     4.0.12                   pypi_0    pypi
# gitpython                 3.1.44                   pypi_0    pypi
# h11                       0.16.0                   pypi_0    pypi
# hf-xet                    1.1.5                    pypi_0    pypi
# httpcore                  1.0.9                    pypi_0    pypi
# httpx                     0.28.1                   pypi_0    pypi
# huggingface-hub           0.33.1                   pypi_0    pypi
# idna                      3.10                     pypi_0    pypi
# import-ipynb              0.2                      pypi_0    pypi
# ipykernel                 6.29.5                   pypi_0    pypi
# ipython                   9.3.0                    pypi_0    pypi
# ipython-pygments-lexers   1.1.1                    pypi_0    pypi
# ipywidgets                8.1.7                    pypi_0    pypi
# isoduration               20.11.0                  pypi_0    pypi
# jaxtyping                 0.3.2                    pypi_0    pypi
# jedi                      0.19.2                   pypi_0    pypi
# jinja2                    3.1.6                    pypi_0    pypi
# joblib                    1.5.1                    pypi_0    pypi
# json5                     0.12.0                   pypi_0    pypi
# jsonpointer               3.0.0                    pypi_0    pypi
# jsonschema                4.24.0                   pypi_0    pypi
# jsonschema-specifications 2025.4.1                 pypi_0    pypi
# jupyter                   1.1.1                    pypi_0    pypi
# jupyter-client            8.6.3                    pypi_0    pypi
# jupyter-console           6.6.3                    pypi_0    pypi
# jupyter-core              5.8.1                    pypi_0    pypi
# jupyter-events            0.12.0                   pypi_0    pypi
# jupyter-lsp               2.2.5                    pypi_0    pypi
# jupyter-server            2.16.0                   pypi_0    pypi
# jupyter-server-terminals  0.5.3                    pypi_0    pypi
# jupyterlab                4.4.4                    pypi_0    pypi
# jupyterlab-pygments       0.3.0                    pypi_0    pypi
# jupyterlab-server         2.27.3                   pypi_0    pypi
# jupyterlab-widgets        3.0.15                   pypi_0    pypi
# kiwisolver                1.4.8                    pypi_0    pypi
# ld_impl_linux-64          2.43                 h1423503_5    conda-forge
# libexpat                  2.7.0                h5888daf_0    conda-forge
# libffi                    3.4.6                h2dba641_1    conda-forge
# libgcc                    15.1.0               h767d61c_3    conda-forge
# libgcc-ng                 15.1.0               h69a702a_3    conda-forge
# libgomp                   15.1.0               h767d61c_3    conda-forge
# liblzma                   5.8.1                hb9d3cd8_2    conda-forge
# libnsl                    2.0.1                hb9d3cd8_1    conda-forge
# libsqlite                 3.50.1               h6cd9bfd_7    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# markdown-it-py            3.0.0                    pypi_0    pypi
# markupsafe                3.0.2                    pypi_0    pypi
# matplotlib                3.10.3                   pypi_0    pypi
# matplotlib-inline         0.1.7                    pypi_0    pypi
# mdurl                     0.1.2                    pypi_0    pypi
# mistune                   3.1.3                    pypi_0    pypi
# mpmath                    1.3.0                    pypi_0    pypi
# multidict                 6.6.2                    pypi_0    pypi
# multiprocess              0.70.16                  pypi_0    pypi
# narwhals                  1.44.0                   pypi_0    pypi
# nbclient                  0.10.2                   pypi_0    pypi
# nbconvert                 7.16.6                   pypi_0    pypi
# nbformat                  5.10.4                   pypi_0    pypi
# ncurses                   6.5                  h2d0b736_3    conda-forge
# nest-asyncio              1.6.0                    pypi_0    pypi
# networkx                  3.3                      pypi_0    pypi
# notebook                  7.4.3                    pypi_0    pypi
# notebook-shim             0.2.4                    pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# nvidia-cublas-cu12        12.8.3.14                pypi_0    pypi
# nvidia-cuda-cupti-cu12    12.8.57                  pypi_0    pypi
# nvidia-cuda-nvrtc-cu12    12.8.61                  pypi_0    pypi
# nvidia-cuda-runtime-cu12  12.8.57                  pypi_0    pypi
# nvidia-cudnn-cu12         9.7.1.26                 pypi_0    pypi
# nvidia-cufft-cu12         11.3.3.41                pypi_0    pypi
# nvidia-cufile-cu12        1.13.0.11                pypi_0    pypi
# nvidia-curand-cu12        10.3.9.55                pypi_0    pypi
# nvidia-cusolver-cu12      11.7.2.55                pypi_0    pypi
# nvidia-cusparse-cu12      12.5.7.53                pypi_0    pypi
# nvidia-cusparselt-cu12    0.6.3                    pypi_0    pypi
# nvidia-nccl-cu12          2.26.2                   pypi_0    pypi
# nvidia-nvjitlink-cu12     12.8.61                  pypi_0    pypi
# nvidia-nvtx-cu12          12.8.55                  pypi_0    pypi
# openssl                   3.5.0                h7b32b05_1    conda-forge
# overrides                 7.7.0                    pypi_0    pypi
# packaging                 25.0                     pypi_0    pypi
# pandas                    2.3.0                    pypi_0    pypi
# pandocfilters             1.5.1                    pypi_0    pypi
# parso                     0.8.4                    pypi_0    pypi
# pexpect                   4.9.0                    pypi_0    pypi
# pillow                    11.2.1                   pypi_0    pypi
# pip                       25.1.1             pyh8b19718_0    conda-forge
# platformdirs              4.3.8                    pypi_0    pypi
# plotly                    6.2.0                    pypi_0    pypi
# prometheus-client         0.22.1                   pypi_0    pypi
# prompt-toolkit            3.0.51                   pypi_0    pypi
# propcache                 0.3.2                    pypi_0    pypi
# protobuf                  6.31.1                   pypi_0    pypi
# psutil                    7.0.0                    pypi_0    pypi
# ptyprocess                0.7.0                    pypi_0    pypi
# pure-eval                 0.2.3                    pypi_0    pypi
# pyarrow                   20.0.0                   pypi_0    pypi
# pycparser                 2.22                     pypi_0    pypi
# pydantic                  2.11.7                   pypi_0    pypi
# pydantic-core             2.33.2                   pypi_0    pypi
# pygments                  2.19.2                   pypi_0    pypi
# pyparsing                 3.2.3                    pypi_0    pypi
# python                    3.11.13         h9e4cc4f_0_cpython    conda-forge
# python-dateutil           2.9.0.post0              pypi_0    pypi
# python-json-logger        3.3.0                    pypi_0    pypi
# pytz                      2025.2                   pypi_0    pypi
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     27.0.0                   pypi_0    pypi
# readline                  8.2                  h8c095d6_2    conda-forge
# referencing               0.36.2                   pypi_0    pypi
# regex                     2024.11.6                pypi_0    pypi
# requests                  2.32.4                   pypi_0    pypi
# rfc3339-validator         0.1.4                    pypi_0    pypi
# rfc3986-validator         0.1.1                    pypi_0    pypi
# rich                      14.0.0                   pypi_0    pypi
# rpds-py                   0.25.1                   pypi_0    pypi
# safetensors               0.5.3                    pypi_0    pypi
# scikit-learn              1.7.0                    pypi_0    pypi
# scipy                     1.16.0                   pypi_0    pypi
# send2trash                1.8.3                    pypi_0    pypi
# sentencepiece             0.2.0                    pypi_0    pypi
# sentry-sdk                2.32.0                   pypi_0    pypi
# setproctitle              1.3.6                    pypi_0    pypi
# setuptools                80.9.0             pyhff2d567_0    conda-forge
# six                       1.17.0                   pypi_0    pypi
# smmap                     5.0.2                    pypi_0    pypi
# sniffio                   1.3.1                    pypi_0    pypi
# soupsieve                 2.7                      pypi_0    pypi
# stack-data                0.6.3                    pypi_0    pypi
# sympy                     1.13.3                   pypi_0    pypi
# terminado                 0.18.1                   pypi_0    pypi
# threadpoolctl             3.6.0                    pypi_0    pypi
# tinycss2                  1.4.0                    pypi_0    pypi
# tk                        8.6.13          noxft_hd72426e_102    conda-forge
# tokenizers                0.21.2                   pypi_0    pypi
# torch                     2.7.1+cu128              pypi_0    pypi
# tornado                   6.5.1                    pypi_0    pypi
# tqdm                      4.67.1                   pypi_0    pypi
# traitlets                 5.14.3                   pypi_0    pypi
# transformer-lens          2.16.1                   pypi_0    pypi
# transformers              4.53.0                   pypi_0    pypi
# transformers-stream-generator 0.0.5                    pypi_0    pypi
# triton                    3.3.1                    pypi_0    pypi
# typeguard                 4.4.4                    pypi_0    pypi
# types-python-dateutil     2.9.0.20250516           pypi_0    pypi
# typing-extensions         4.14.0                   pypi_0    pypi
# typing-inspection         0.4.1                    pypi_0    pypi
# tzdata                    2025.2                   pypi_0    pypi
# uri-template              1.3.0                    pypi_0    pypi
# urllib3                   2.5.0                    pypi_0    pypi
# wadler-lindig             0.1.7                    pypi_0    pypi
# wandb                     0.20.1                   pypi_0    pypi
# wcwidth                   0.2.13                   pypi_0    pypi
# webcolors                 24.11.1                  pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.8.0                    pypi_0    pypi
# wheel                     0.45.1             pyhd8ed1ab_1    conda-forge
# widgetsnbextension        4.0.14                   pypi_0    pypi
# xxhash                    3.5.0                    pypi_0    pypi
# yarl                      1.20.1                   pypi_0    pypi

# %% [markdown]
# **Using Cuda 12.8 with PyTorch**

# %%
# %pip install torch --index-url https://download.pytorch.org/whl/cu128
# %pip install numpy
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Requirement already satisfied: torch in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (2.7.1+cu128)
# Requirement already satisfied: filelock in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.61 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.8.61)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.57 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.8.57)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.57 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.8.57)
# Requirement already satisfied: nvidia-cudnn-cu12==9.7.1.26 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (9.7.1.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.3.14 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.8.3.14)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.41 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (11.3.3.41)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.55 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (10.3.9.55)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.2.55 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (11.7.2.55)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.7.53 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.5.7.53)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.55 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.8.55)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.61 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (12.8.61)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.0.11 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (1.13.0.11)
# Requirement already satisfied: triton==3.3.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from triton==3.3.1->torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **test to see if torch is installed:**

# %%
import torch

# %%
# Note: V100 GPU too old for Conda 12.8
# Use: A100 or higher
# !python -c "import torch; print(torch.cuda.is_available(), torch.cuda.get_device_name(0))"
# Out:
# True NVIDIA A100-PCIE-40GB

# %% [markdown]
# # Other Required Packages
#
# Note: no need to run these cells once the CoxeterEnv (python environment) has been setup, since these packages are already installed

# %% [markdown]
# ## Code Generation

# %%
# %pip install pandas numpy import-ipynb matplotlib scikit-learn plotly
# Out:
# Requirement already satisfied: pandas in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: numpy in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: import-ipynb in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (0.2)
# Requirement already satisfied: matplotlib in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (3.10.3)
# Requirement already satisfied: scikit-learn in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: IPython in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from import-ipynb) (9.3.0)
# Requirement already satisfied: nbformat in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: contourpy>=1.0.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: decorator in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (2.19.2)
# Requirement already satisfied: stack_data in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from IPython->import-ipynb) (4.14.0)
# Requirement already satisfied: wcwidth in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from nbformat->import-ipynb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from nbformat->import-ipynb) (4.24.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from nbformat->import-ipynb) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.8)
# Requirement already satisfied: executing>=1.2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from stack_data->IPython->import-ipynb) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from stack_data->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure-eval in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from stack_data->IPython->import-ipynb) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Transformer Training/ML Packages

# %%
# %pip install transformer-lens einops fancy-einsum tqdm plotly transformers datasets ipython
# Out:
# Requirement already satisfied: transformer-lens in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (2.16.1)
# Requirement already satisfied: einops in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (0.8.1)
# Requirement already satisfied: fancy-einsum in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (0.0.3)
# Requirement already satisfied: tqdm in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: plotly in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (6.2.0)
# Requirement already satisfied: transformers in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (4.53.0)
# Requirement already satisfied: datasets in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: ipython in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (9.3.0)
# Requirement already satisfied: accelerate>=0.23.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (1.8.1)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (0.3.2)
# Requirement already satisfied: numpy<2,>=1.24 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (2.3.0)
# Requirement already satisfied: rich>=12.6.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (14.0.0)
# Requirement already satisfied: sentencepiece in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (0.2.0)
# Requirement already satisfied: torch>=2.6 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (2.7.1+cu128)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (4.4.4)
# Requirement already satisfied: typing-extensions in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (4.14.0)
# Requirement already satisfied: wandb>=0.13.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformer-lens) (0.20.1)
# Requirement already satisfied: narwhals>=1.15.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from plotly) (1.44.0)
# Requirement already satisfied: packaging in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from plotly) (25.0)
# Requirement already satisfied: filelock in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (0.33.1)
# Requirement already satisfied: pyyaml>=5.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from datasets) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.13)
# Requirement already satisfied: decorator in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: psutil in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer-lens) (7.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.2)
# Requirement already satisfied: propcache>=0.2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jaxtyping>=0.2.11->transformer-lens) (0.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pandas>=1.1.5->transformer-lens) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pandas>=1.1.5->transformer-lens) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pandas>=1.1.5->transformer-lens) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: six>=1.5 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer-lens) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from rich>=12.6.0->transformer-lens) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens) (0.1.2)
# Requirement already satisfied: sympy>=1.13.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (1.13.3)
# Requirement already satisfied: networkx in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (3.3)
# Requirement already satisfied: jinja2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.61 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.8.61)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.57 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.8.57)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.57 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.8.57)
# Requirement already satisfied: nvidia-cudnn-cu12==9.7.1.26 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (9.7.1.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.3.14 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.8.3.14)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.41 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (11.3.3.41)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.55 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (10.3.9.55)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.2.55 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (11.7.2.55)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.7.53 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.5.7.53)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.55 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.8.55)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.61 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (12.8.61)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.0.11 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (1.13.0.11)
# Requirement already satisfied: triton==3.3.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from torch>=2.6->transformer-lens) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from triton==3.3.1->torch>=2.6->transformer-lens) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.6->transformer-lens) (1.3.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (3.1.44)
# Requirement already satisfied: platformdirs in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (6.31.1)
# Requirement already satisfied: pydantic<3 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (2.32.0)
# Requirement already satisfied: setproctitle in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer-lens) (1.3.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens) (0.4.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from jinja2->torch>=2.6->transformer-lens) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from stack_data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in /projects/expmmllab/CoxeterEnv/lib/python3.11/site-packages (from stack_data->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
